# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install SpeechRecognition
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 10.4 MB/s eta 0:00:00
# ...

# %%
import os
import random
import shutil
import numpy as np
import moviepy.editor as mp
#import speech_recognition as sr
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if event.key is 'enter':

# %%
import os
import random

# Đường dẫn tới thư mục chứa các file cần xáo trộn và đổi tên
folder_path = '/content/drive/MyDrive/TieuLuan/data/consensus/video'  # Thay đổi đường dẫn tới thư mục của bạn

# Lấy danh sách tên file trong thư mục
file_names = os.listdir(folder_path)

# Xáo trộn danh sách tên file
random.shuffle(file_names)

# Đổi tên các file theo thứ tự xáo trộn
for i, file_name in enumerate(file_names):
    file_path = os.path.join(folder_path, file_name)
    file_extension = os.path.splitext(file_name)[1]
    new_file_name = f"{i + 1}{file_extension}"  # Đổi tên file thành số thứ tự
    new_file_path = os.path.join(folder_path, new_file_name)
    os.rename(file_path, new_file_path)

# %%
import pandas as pd
import random

# Đọc file CSV từ Google Drive
file_path = '/content/drive/MyDrive/TieuLuan/data/data_text/train.csv'
df = pd.read_csv(file_path)

# Lọc các dòng không có NaN trong cột 'label' (hoặc cột khác nếu cần)
df_filtered = df[df['label'].notna()]

# Lấy danh sách các nhãn từ cột 'label'
labels = df_filtered['label'].tolist()

# Xáo trộn nhãn ngẫu nhiên
random.shuffle(labels)

# Gán lại các nhãn đã xáo trộn vào cột 'label' trong DataFrame
df_filtered['label'] = labels

# Hiển thị DataFrame đã lọc (không có NaN trong cột 'label')
df_filtered
# Out:
#           name         label  \
# 0     0001.mp4     offensive
# 1     0002.mp4       violent
# 2     0003.mp4      horrible
# 3     0004.mp4     offensive
# 4     0005.mp4  pornographic
# ...        ...           ...
# 1272  0318.mp4     offensive
# 1273  0319.mp4        normal
# 1274  0320.mp4  pornographic
# 1275  0321.mp4  pornographic
# 1276  0322.mp4  pornographic
#
#                                                    text
# 0     chỗ này là giáp ranh biên giới với lại Viêng C...
# 1     không tập trung các cái môn nền tảng là rất là...
# 2     chim có 's-link lập trình viên quan trọng bậc ...
# 3     rộng 9 mét vuông là hiểu giá thuê đã làm người...
# 4                                                   NaN
# ...                                                 ...
# 1272                                     How to my wife
# 1273                                                NaN
# 1274  con cá sấu mở miệng rộng và người thanh niên n...
# ...

# %% [markdown]
# # Di chuyển file

# %%
def move_files(source_folder, destination_folder):
    for filename in os.listdir(source_folder):
        source_path = os.path.join(source_folder, filename)
        destination_path = os.path.join(destination_folder, filename)

        shutil.move(source_path, destination_path)
        print("Moved file: {}".format(filename))

# %%
source_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/test/horrible'
destination_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/train/horrible'
move_files(source_folder, destination_folder)

# %% [markdown]
# # Xóa file

# %%
import os

folder_path = '/content/drive/MyDrive/TieuLuan/data/data_spec/val/violent'

# Lấy danh sách các file trong thư mục
file_list = os.listdir(folder_path)

# Xóa từng file trong danh sách
for file_name in file_list:
    file_path = os.path.join(folder_path, file_name)
    os.remove(file_path)

print("Đã xóa hết các file trong thư mục.")
# Out:
# Đã xóa hết các file trong thư mục.

# %% [markdown]
# # Chia train, test, val

# %%
def split_videos(train_folder, test_folder, val_folder, test_ratio=0.1, val_ratio=0.1):

    video_list = os.listdir(train_folder)
    random.shuffle(video_list)

    total_videos = len(video_list)
    num_test_videos = int(total_videos * test_ratio)
    num_val_videos = int(total_videos * val_ratio)

    for i in range(num_test_videos):
        video_name = video_list[i]
        video_path = os.path.join(train_folder, video_name)
        destination_path = os.path.join(test_folder, video_name)
        shutil.move(video_path, destination_path)
        print("Moved file '{}' to {}".format(video_name, test_folder))

    for i in range(num_test_videos, num_test_videos + num_val_videos):
        video_name = video_list[i]
        video_path = os.path.join(train_folder, video_name)
        destination_path = os.path.join(val_folder, video_name)
        shutil.move(video_path, destination_path)
        print("Moved file '{}' to {}".format(video_name, val_folder))

# %%
train_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/train/horrible'
test_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/test/horrible'
val_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/val/horrible'

test_ratio = 0.1
val_ratio = 0.1
split_videos(train_folder, test_folder, val_folder, test_ratio, val_ratio)

# %% [markdown]
# # Đếm file

# %%
import os

folder_path = '/content/drive/MyDrive/TieuLuan/data/data_video/test/offensive'

# Lấy danh sách các file trong thư mục
file_list = os.listdir(folder_path)

# Đếm số lượng file
num_files = len(file_list)

print("Số lượng file trong thư mục:", num_files)
# Out:
# Số lượng file trong thư mục: 31

# %% [markdown]
# # Đổi tên file

# %%
import os

# Đường dẫn đến thư mục chứa video
data_dir = '/content/drive/MyDrive/TieuLuan/data/consensus/video'

video_files = os.listdir(data_dir)

for i, video_file in enumerate(video_files):
    video_path = os.path.join(data_dir, video_file)
    new_video_name = '{:04d}.mp4'.format(i + 1)  # Định dạng tên mới: 0001.mp4, 0002.mp4, ...
    new_video_path = os.path.join(data_dir, new_video_name)
    os.rename(video_path, new_video_path)

# %% [markdown]
# # Speech to Text

# %%
import csv
import speech_recognition as sr
from moviepy.editor import VideoFileClip

# %%
def extract_video_text(input_directory, label, output_csv):
    video_directory = os.path.join(input_directory, label)
    videos = sorted(os.listdir(video_directory))

    with open(output_csv, 'a', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)

        for video in videos:
            video_path = os.path.join(video_directory, video)

            # Trích xuất văn bản từ âm thanh của video
            recognizer = sr.Recognizer()
            video_clip = VideoFileClip(video_path)
            audio_clip = video_clip.audio
            audio_path = 'temp.wav'
            audio_clip.write_audiofile(audio_path)
            text = ""

            try:
                with sr.AudioFile(audio_path) as audio:
                    audio_data = recognizer.record(audio)
                    text = recognizer.recognize_google(audio_data, language='vi-VN')
            except sr.UnknownValueError:
                print(f"Không thể nhận dạng văn bản từ file {video}. Bỏ qua...")

            os.remove(audio_path)

            writer.writerow([video, label, text])

    print("Trích xuất và lưu văn bản thành công.")

# %% [markdown]
# # test

# %%
output_csv = '/content/drive/MyDrive/TieuLuan/data/data_text/test.csv'
with open(output_csv, 'a', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['name', 'label', 'text'])

# %%
input_directory = '/content/drive/MyDrive/TieuLuan/data/data_video/test'
label = 'normal'

extract_video_text(input_directory, label, output_csv)
# Out:
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0004.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0008.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0010.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0012.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# ...

# %%
input_directory = '/content/drive/MyDrive/TieuLuan/data/data_video/test'
label = 'horrible'

extract_video_text(input_directory, label, output_csv)
# Out:
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0001.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0005.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0007.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0008.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0009.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# ...

# %%
input_directory = '/content/drive/MyDrive/TieuLuan/data/data_video/test'
label = 'offensive'

extract_video_text(input_directory, label, output_csv)
# Out:
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0001.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0002.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0004.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0007.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0009.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0010.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# ...

# %%
input_directory = '/content/drive/MyDrive/TieuLuan/data/data_video/test'
label = 'pornographic'

extract_video_text(input_directory, label, output_csv)
# Out:
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0001.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0002.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0003.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0004.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0006.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0007.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0008.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0009.mp4. Bỏ qua...
# ...

# %%
input_directory = '/content/drive/MyDrive/TieuLuan/data/data_video/test'
label = 'violent'

extract_video_text(input_directory, label, output_csv)
# Out:
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0004.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0005.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# ...

# %% [markdown]
# # val

# %%
output_csv = '/content/drive/MyDrive/TieuLuan/data/data_text/val.csv'
with open(output_csv, 'a', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['name', 'label', 'text'])

# %%
input_directory = '/content/drive/MyDrive/TieuLuan/data/data_video/val'
label = 'normal'

extract_video_text(input_directory, label, output_csv)
# Out:
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0006.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0014.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# ...

# %%
input_directory = '/content/drive/MyDrive/TieuLuan/data/data_video/val'
label = 'horrible'

extract_video_text(input_directory, label, output_csv)
# Out:
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0001.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0008.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0009.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0010.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0012.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# ...

# %%
input_directory = '/content/drive/MyDrive/TieuLuan/data/data_video/val'
label = 'offensive'

extract_video_text(input_directory, label, output_csv)
# Out:
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0002.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0005.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0008.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0009.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0010.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0011.mp4. Bỏ qua...
# ...

# %%
input_directory = '/content/drive/MyDrive/TieuLuan/data/data_video/val'
label = 'pornographic'

extract_video_text(input_directory, label, output_csv)
# Out:
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0001.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0002.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0003.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0004.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0005.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0006.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0007.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0008.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# ...

# %%
input_directory = '/content/drive/MyDrive/TieuLuan/data/data_video/val'
label = 'violent'

extract_video_text(input_directory, label, output_csv)
# Out:
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0001.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0003.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0007.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0008.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0009.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0010.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# ...

# %% [markdown]
# # train

# %%
output_csv = '/content/drive/MyDrive/TieuLuan/data/data_text/train.csv'
with open(output_csv, 'a', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['name', 'label', 'text'])

# %%
input_directory = '/content/drive/MyDrive/TieuLuan/data/data_video/train'
label = 'normal'

extract_video_text(input_directory, label, output_csv)
# Out:
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0005.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0006.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0007.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# ...

# %%
input_directory = '/content/drive/MyDrive/TieuLuan/data/data_video/train'
label = 'horrible'

extract_video_text(input_directory, label, output_csv)
# Out:
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0001.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0002.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0003.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0004.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0005.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0010.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# ...

# %%
input_directory = '/content/drive/MyDrive/TieuLuan/data/data_video/train'
label = 'offensive'

extract_video_text(input_directory, label, output_csv)
# Out:
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0001.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0002.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0004.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0005.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0006.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0007.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0009.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# ...

# %%
input_directory = '/content/drive/MyDrive/TieuLuan/data/data_video/train'
label = 'pornographic'

extract_video_text(input_directory, label, output_csv)
# Out:
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0001.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0002.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0003.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0006.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0008.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0009.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0010.mp4. Bỏ qua...
# ...

# %%
input_directory = '/content/drive/MyDrive/TieuLuan/data/data_video/train'
label = 'violent'

extract_video_text(input_directory, label, output_csv)
# Out:
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0001.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0002.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0004.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0007.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# MoviePy - Writing audio in temp.wav
# MoviePy - Done.
# Không thể nhận dạng văn bản từ file 0012.mp4. Bỏ qua...
# MoviePy - Writing audio in temp.wav
# ...

# %% [markdown]
# # Spectrogram

# %%
# !pip install librosa moviepy

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import librosa
import moviepy.editor as mp

def extract_spectrograms_from_videos(video_folder, spectrogram_folder):
    for filename in os.listdir(video_folder):
        if filename.endswith('.mp4'):
            video_path = os.path.join(video_folder, filename)

            try:
                # Sử dụng moviepy để tải audio từ video
                video = mp.VideoFileClip(video_path)
                audio = video.audio
                audio_path = os.path.join(video_folder, "temp_audio.wav")
                audio.write_audiofile(audio_path, codec='pcm_s16le')  # Lưu âm thanh thành file WAV

                # Dùng librosa để load audio
                y, sr = librosa.load(audio_path, sr=None)  # sr=None để sử dụng sample rate gốc

                # Tạo spectrogram using librosa's stft
                frequencies, times, spectrogram = signal.spectrogram(y, fs=sr, nperseg=1024, noverlap=512)

                # Vẽ spectrogram
                plt.figure(figsize=(10, 10))
                plt.pcolormesh(times, frequencies, 10 * np.log10(spectrogram), shading='auto', cmap='inferno')
                plt.axis('off')
                plt.tight_layout()

                # Lưu spectrogram vào thư mục
                spectrogram_filename = os.path.splitext(filename)[0] + '.png'
                spectrogram_path = os.path.join(spectrogram_folder, spectrogram_filename)
                plt.savefig(spectrogram_path)
                plt.close()

                print("Spectrogram saved for {}".format(filename))

                # Xóa file âm thanh tạm thời
                os.remove(audio_path)

            except Exception as e:
                print(f"Skipping {filename} due to error: {e}")  # In ra thông báo lỗi và bỏ qua video hiện tại
                continue  # Chuyển sang file video tiếp theo

# %% [markdown]
# # test

# %%
video_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/test/horrible'
spectrogram_folder = '/content/drive/MyDrive/TieuLuan/data/data_spec/test/horrible'

extract_spectrograms_from_videos(video_folder, spectrogram_folder)
# Out:
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/horrible/temp_audio.wav
# WARNING:py.warnings:<ipython-input-61-00a7eecbab12>:28: RuntimeWarning: divide by zero encountered in log10
#   plt.pcolormesh(times, frequencies, 10 * np.log10(spectrogram), shading='auto', cmap='inferno')
# MoviePy - Done.
# Spectrogram saved for 0006.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/horrible/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0010.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/horrible/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0019.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/horrible/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0009.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/horrible/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0011.mp4
# ...

# %%
video_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/test/normal'
spectrogram_folder = '/content/drive/MyDrive/TieuLuan/data/data_spec/test/normal'

extract_spectrograms_from_videos(video_folder, spectrogram_folder)
# Out:
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/normal/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0001.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/normal/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0019.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/normal/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0012.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/normal/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0022.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/normal/temp_audio.wav
# WARNING:py.warnings:<ipython-input-61-00a7eecbab12>:28: RuntimeWarning: divide by zero encountered in log10
#   plt.pcolormesh(times, frequencies, 10 * np.log10(spectrogram), shading='auto', cmap='inferno')
# MoviePy - Done.
# Spectrogram saved for 0029.mp4
# ...

# %%
video_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/test/offensive'
spectrogram_folder = '/content/drive/MyDrive/TieuLuan/data/data_spec/test/offensive'

extract_spectrograms_from_videos(video_folder, spectrogram_folder)
# Out:
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/offensive/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0014.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/offensive/temp_audio.wav
# WARNING:py.warnings:<ipython-input-61-00a7eecbab12>:28: RuntimeWarning: divide by zero encountered in log10
#   plt.pcolormesh(times, frequencies, 10 * np.log10(spectrogram), shading='auto', cmap='inferno')
# MoviePy - Done.
# Spectrogram saved for 0019.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/offensive/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0021.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/offensive/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0004.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/offensive/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0020.mp4
# ...

# %%
video_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/test/pornographic'
spectrogram_folder = '/content/drive/MyDrive/TieuLuan/data/data_spec/test/pornographic'

extract_spectrograms_from_videos(video_folder, spectrogram_folder)
# Out:
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/pornographic/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0011.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/pornographic/temp_audio.wav
# WARNING:py.warnings:<ipython-input-61-00a7eecbab12>:28: RuntimeWarning: divide by zero encountered in log10
#   plt.pcolormesh(times, frequencies, 10 * np.log10(spectrogram), shading='auto', cmap='inferno')
# MoviePy - Done.
# Spectrogram saved for 0004.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/pornographic/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0003.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/pornographic/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0005.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/pornographic/temp_audio.wav
# MoviePy - Done.
# ...

# %%
video_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/test/violent'
spectrogram_folder = '/content/drive/MyDrive/TieuLuan/data/data_spec/test/violent'

extract_spectrograms_from_videos(video_folder, spectrogram_folder)
# Out:
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/violent/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0001.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/violent/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0019.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/violent/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0026.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/violent/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0015.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/test/violent/temp_audio.wav
# WARNING:py.warnings:<ipython-input-61-00a7eecbab12>:28: RuntimeWarning: divide by zero encountered in log10
#   plt.pcolormesh(times, frequencies, 10 * np.log10(spectrogram), shading='auto', cmap='inferno')
# MoviePy - Done.
# Spectrogram saved for 0025.mp4
# ...

# %% [markdown]
# # Val

# %%
video_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/val/horrible'
spectrogram_folder = '/content/drive/MyDrive/TieuLuan/data/data_spec/val/horrible'

extract_spectrograms_from_videos(video_folder, spectrogram_folder)
# Out:
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/horrible/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0001.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/horrible/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0015.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/horrible/temp_audio.wav
# MoviePy - Done.
# WARNING:py.warnings:<ipython-input-1-00a7eecbab12>:28: RuntimeWarning: divide by zero encountered in log10
#   plt.pcolormesh(times, frequencies, 10 * np.log10(spectrogram), shading='auto', cmap='inferno')
# Spectrogram saved for 0008.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/horrible/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0021.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/horrible/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0017.mp4
# ...

# %%
video_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/val/normal'
spectrogram_folder = '/content/drive/MyDrive/TieuLuan/data/data_spec/val/normal'

extract_spectrograms_from_videos(video_folder, spectrogram_folder)
# Out:
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/normal/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0007.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/normal/temp_audio.wav
# WARNING:py.warnings:<ipython-input-1-00a7eecbab12>:28: RuntimeWarning: divide by zero encountered in log10
#   plt.pcolormesh(times, frequencies, 10 * np.log10(spectrogram), shading='auto', cmap='inferno')
# MoviePy - Done.
# Spectrogram saved for 0015.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/normal/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0012.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/normal/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0017.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/normal/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0022.mp4
# ...

# %%
video_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/val/offensive'
spectrogram_folder = '/content/drive/MyDrive/TieuLuan/data/data_spec/val/offensive'

extract_spectrograms_from_videos(video_folder, spectrogram_folder)
# Out:
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/offensive/temp_audio.wav
# WARNING:py.warnings:<ipython-input-1-00a7eecbab12>:28: RuntimeWarning: divide by zero encountered in log10
#   plt.pcolormesh(times, frequencies, 10 * np.log10(spectrogram), shading='auto', cmap='inferno')
# MoviePy - Done.
# Spectrogram saved for 0021.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/offensive/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0027.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/offensive/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0025.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/offensive/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0001.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/offensive/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0015.mp4
# ...

# %%
video_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/val/pornographic'
spectrogram_folder = '/content/drive/MyDrive/TieuLuan/data/data_spec/val/pornographic'

extract_spectrograms_from_videos(video_folder, spectrogram_folder)
# Out:
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/pornographic/temp_audio.wav
# WARNING:py.warnings:<ipython-input-1-00a7eecbab12>:28: RuntimeWarning: divide by zero encountered in log10
#   plt.pcolormesh(times, frequencies, 10 * np.log10(spectrogram), shading='auto', cmap='inferno')
# MoviePy - Done.
# Spectrogram saved for 0030.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/pornographic/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0012.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/pornographic/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0002.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/pornographic/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0018.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/pornographic/temp_audio.wav
# MoviePy - Done.
# ...

# %%
video_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/val/violent'
spectrogram_folder = '/content/drive/MyDrive/TieuLuan/data/data_spec/val/violent'

extract_spectrograms_from_videos(video_folder, spectrogram_folder)
# Out:
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/violent/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0002.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/violent/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0001.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/violent/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0019.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/violent/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0008.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/violent/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0039.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/val/violent/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0030.mp4
# ...

# %% [markdown]
# # train

# %%
video_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/train/horrible'
spectrogram_folder = '/content/drive/MyDrive/TieuLuan/data/data_spec/train/horrible'

extract_spectrograms_from_videos(video_folder, spectrogram_folder)
# Out:
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/horrible/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0074.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/horrible/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0131.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/horrible/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0136.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/horrible/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0044.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/horrible/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0174.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/horrible/temp_audio.wav
# ...

# %%
video_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/train/normal'
spectrogram_folder = '/content/drive/MyDrive/TieuLuan/data/data_spec/train/normal'

extract_spectrograms_from_videos(video_folder, spectrogram_folder)
# Out:
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/normal/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0051.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/normal/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0019.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/normal/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0084.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/normal/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0071.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/normal/temp_audio.wav
# WARNING:py.warnings:<ipython-input-6-00a7eecbab12>:28: RuntimeWarning: divide by zero encountered in log10
#   plt.pcolormesh(times, frequencies, 10 * np.log10(spectrogram), shading='auto', cmap='inferno')
# MoviePy - Done.
# Spectrogram saved for 0011.mp4
# ...

# %%
video_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/train/offensive'
spectrogram_folder = '/content/drive/MyDrive/TieuLuan/data/data_spec/train/offensive'

extract_spectrograms_from_videos(video_folder, spectrogram_folder)
# Out:
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/offensive/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0019.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/offensive/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0061.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/offensive/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0119.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/offensive/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0090.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/offensive/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0181.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/offensive/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0023.mp4
# ...

# %%
video_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/train/pornographic'
spectrogram_folder = '/content/drive/MyDrive/TieuLuan/data/data_spec/train/pornographic'

extract_spectrograms_from_videos(video_folder, spectrogram_folder)
# Out:
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/pornographic/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0122.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/pornographic/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0256.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/pornographic/temp_audio.wav
# WARNING:py.warnings:<ipython-input-6-00a7eecbab12>:28: RuntimeWarning: divide by zero encountered in log10
#   plt.pcolormesh(times, frequencies, 10 * np.log10(spectrogram), shading='auto', cmap='inferno')
# MoviePy - Done.
# Spectrogram saved for 0138.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/pornographic/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0156.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/pornographic/temp_audio.wav
# MoviePy - Done.
# ...

# %%
video_folder = '/content/drive/MyDrive/TieuLuan/data/data_video/train/violent'
spectrogram_folder = '/content/drive/MyDrive/TieuLuan/data/data_spec/train/violent'

extract_spectrograms_from_videos(video_folder, spectrogram_folder)
# Out:
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/violent/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0264.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/violent/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0285.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/violent/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0204.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/violent/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0168.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/violent/temp_audio.wav
# MoviePy - Done.
# Spectrogram saved for 0065.mp4
# MoviePy - Writing audio in /content/drive/MyDrive/TieuLuan/data/data_video/train/violent/temp_audio.wav
# WARNING:py.warnings:<ipython-input-6-00a7eecbab12>:28: RuntimeWarning: divide by zero encountered in log10
# ...
